# %%
import os
import pandas as pd

# %%
path = "../data/photometry/"

# %%
pd.read_csv(open(os.path.join(path, '0800-1/3201-0800-1-BOX5-photometry.csv')), sep = " ",  index_col = False)
# Out:
#         Item6.Timestamp.TimeOfDay.TotalMilliseconds  \
# 0                                      5.651216e+07
# 1                                      5.651219e+07
# 2                                      5.651221e+07
# 3                                      5.651224e+07
# 4                                      5.651226e+07
# ...                                             ...
# 222775                                 6.208134e+07
# 222776                                 6.208137e+07
# 222777                                 6.208140e+07
# 222778                                 6.208142e+07
# 222779                                 6.208144e+07
#
#         Item4.Timestamp.TimeOfDay.TotalMilliseconds  Item5.Val0  Item5.Val1  \
# 0                                      5.651216e+07       25963           0
# 1                                      5.651219e+07       65335           0
# 2                                      5.651221e+07       25807           0
# ...
